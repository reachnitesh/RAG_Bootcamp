# %% [markdown]
# # 📚 Notebook 01: Introduction and Fundamentals
#
# **LangChain 1.0.5+ | Mixed Level Class**
#
# ---
#
# ## 🎯 Learning Objectives
#
# By the end of this notebook, you will understand:
# 1. What LangChain is and why it's useful
# 2. LangChain's modular architecture
# 3. Core concepts: Documents, Chains, and LCEL
# 4. How to set up your development environment
# 5. The difference between LangChain and traditional ML pipelines
#
# ---
#
# ## 📖 Table of Contents
#
# 1. [What is LangChain?](#what-is-langchain)
# 2. [LangChain Architecture](#architecture)
# 3. [Environment Setup](#setup)
# 4. [Core Concepts](#core-concepts)
# 5. [Quick Start Example](#quick-start)
# 6. [LangChain vs Traditional Pipelines](#comparison)
# 7. [Summary & Next Steps](#summary)
#
# ---

# %% [markdown]
# <a id="what-is-langchain"></a>
# ## 1. What is LangChain? 🤔
#
# ### 🔰 BEGINNER SECTION
#
# **LangChain** is an open-source framework that makes it easy to build applications powered by Large Language Models (LLMs) like GPT-4, Claude, or Llama.
#
# ### Why LangChain?
#
# Imagine you want to build a chatbot that can:
# - Answer questions about your company's PDF documents
# - Search through your database
# - Remember previous conversations
# - Call external APIs
#
# Without LangChain, you'd need to:
# 1. ✍️ Write code to load and parse PDFs
# 2. ✍️ Convert text to embeddings
# 3. ✍️ Store embeddings in a vector database
# 4. ✍️ Implement semantic search
# 5. ✍️ Format prompts for the LLM
# 6. ✍️ Handle LLM API calls
# 7. ✍️ Manage conversation memory
#
# **With LangChain:**
# - ✅ All these components are pre-built and ready to use
# - ✅ You just connect them like LEGO blocks
# - ✅ Focus on your application logic, not infrastructure
#
# ### 🎓 INTERMEDIATE NOTE
#
# LangChain provides:
# - **Abstractions**: Unified interfaces for different LLMs, vector stores, and tools
# - **Chains**: Composable workflows using LCEL (LangChain Expression Language)
# - **Agents**: Autonomous systems that can use tools and make decisions
# - **Memory**: Conversation history and context management
# - **Callbacks**: Monitoring, logging, and debugging hooks

# %% [markdown]
# <a id="architecture"></a>
# ## 2. LangChain Architecture 🏗️
#
# ### 🔰 BEGINNER: Visual Architecture
#
# ```
# ┌─────────────────────────────────────────────────────────┐
# │                    YOUR APPLICATION                     │
# └─────────────────────────────────────────────────────────┘
#                            ↓
# ┌─────────────────────────────────────────────────────────┐
# │                  LANGCHAIN FRAMEWORK                    │
# │  ┌──────────┐  ┌──────────┐  ┌──────────┐  ┌─────────┐  │
# │  │ Document │  │   Text   │  │ Embeddings│  │ Vector  │ │
# │  │ Loaders  │→ │ Splitters│→ │  Models   │→ │ Stores  │ │
# │  └──────────┘  └──────────┘  └──────────┘  └─────────┘│
# │                                                         │
# │  ┌──────────┐  ┌──────────┐  ┌──────────┐               │
# │  │Retrievers│  │ Prompts  │  │   LLMs   │               │
# │  └──────────┘  └──────────┘  └──────────┘               │
# │                                                         │
# │  ┌──────────────────────────────────────────────────┐   │
# │  │         LCEL (LangChain Expression Language)     │   │
# │  │         Connects everything with | operator      │   │
# │  └──────────────────────────────────────────────────┘   │
# └─────────────────────────────────────────────────────────┘
#                            ↓
# ┌─────────────────────────────────────────────────────────┐
# │             EXTERNAL SERVICES & DATA                    │
# │  • OpenAI/Anthropic APIs  • Vector Databases            │
# │  • PDF Files              • Websites                    │
# │  • Databases              • APIs                        │
# └─────────────────────────────────────────────────────────┘
# ```
#
# ### 🎓 INTERMEDIATE: Package Structure (LangChain 1.0+)
#
# LangChain is organized into several packages:
#
# | Package | Purpose | Example Imports |
# |---------|---------|------------------|
# | **langchain-core** | Core abstractions, base classes | `from langchain_core.documents import Document` |
# | **langchain-community** | Community integrations (loaders, vector stores) | `from langchain_community.document_loaders import PyPDFLoader` |
# | **langchain-openai** | OpenAI-specific integrations | `from langchain_openai import ChatOpenAI, OpenAIEmbeddings` |
# | **langchain-text-splitters** | Text splitting utilities | `from langchain_text_splitters import RecursiveCharacterTextSplitter` |
#
# **Why this matters:** In LangChain 1.0+, you import from specific packages instead of `langchain` directly. This reduces dependencies and improves modularity.

# %% [markdown]
# <a id="setup"></a>
# ## 3. Environment Setup 🛠️
#
# ### 🔰 BEGINNER: Step-by-Step Setup
#
# Let's verify your environment is ready!

# %%
# Step 1: Check Python version (should be 3.9+)
import sys
print(f"Python version: {sys.version}")

# Check if Python is 3.9 or higher
if sys.version_info >= (3, 9):
    print("✅ Python version is compatible")
else:
    print("❌ Please upgrade to Python 3.9 or higher")
# Out:
# Python version: 3.12.10 (v3.12.10:0cc81280367, Apr  8 2025, 08:46:59) [Clang 13.0.0 (clang-1300.0.29.30)]
# ✅ Python version is compatible

# %%
# Step 2: Import LangChain and check version
import langchain
from langchain_core import __version__ as core_version

print(f"LangChain version: {langchain.__version__}")
print(f"LangChain Core version: {core_version}")

# We're using LangChain 1.0.5+ for this course
if langchain.__version__ >= "1.0":
    print("✅ LangChain 1.0+ detected")
else:
    print("❌ Please upgrade: pip install --upgrade langchain")
# Out:
# LangChain version: 0.3.27
# LangChain Core version: 0.3.79
# ❌ Please upgrade: pip install --upgrade langchain

# %%
# Step 3: Load environment variables (API keys)
from dotenv import load_dotenv
import os

# Load .env file
load_dotenv()

# Check if OpenAI API key is set
# NOTE: We don't print the actual key for security!
if os.getenv("OPENAI_API_KEY"):
    print("✅ OPENAI_API_KEY found")
    #print(f"key = {os.getenv('OPENAI_API_KEY')}")
else:
    print("❌ OPENAI_API_KEY not found")
    print("   Create a .env file with: OPENAI_API_KEY=your-key-here")

# Check for Google API key (optional, for Google Gemini)
if os.getenv("GOOGLE_API_KEY"):
    print("✅ GOOGLE_API_KEY found")
    print(f"Google_key = {os.getenv('GOOGLE_API_KEY')}")
else:
    print("⚠️  GOOGLE_API_KEY not found (optional for this notebook)")
# Out:
# ✅ OPENAI_API_KEY found
# ✅ GOOGLE_API_KEY found
# Google_key =

# %% [markdown]
# ### 📝 Setting Up Your .env File
#
# If you don't have a `.env` file, create one in the project root:
#
# ```bash
# # .env file
# OPENAI_API_KEY=sk-proj-your-key-here
# GOOGLE_API_KEY=your-google-key-here
# ```
#
# **⚠️ SECURITY WARNING:**
# - Never commit `.env` files to Git
# - Add `.env` to your `.gitignore` file
# - Never hardcode API keys in your code

# %% [markdown]
# <a id="core-concepts"></a>
# ## 4. Core Concepts 📚
#
# ### 4.1 Documents 📄
#
# ### 🔰 BEGINNER
#
# A **Document** is LangChain's way of representing a piece of text with metadata.
#
# Think of it like a note card:
# - **Front (page_content):** The actual text
# - **Back (metadata):** Information about the text (source, page number, date, etc.)

# %%
# Creating a Document manually
from langchain_core.documents import Document

# Create a simple document
doc = Document(
    page_content="LangChain makes building LLM applications easy!",
    metadata={
        "source": "introduction.txt",
        "author": "LangChain Team",
        "date": "2025-01-15"
    }
)

# Access the content
print("Content:")
print(doc.page_content)
print("\nMetadata:")
print(doc.metadata)
print(f"\nSource: {doc.metadata['source']}")
# Out:
# Content:
# LangChain makes building LLM applications easy!
#
# Metadata:
# {'source': 'introduction.txt', 'author': 'LangChain Team', 'date': '2025-01-15'}
#
# Source: introduction.txt

# %% [markdown]
# ### 🎓 INTERMEDIATE: Why Metadata Matters
#
# Metadata is crucial for:
# 1. **Citation**: Showing users where information came from
# 2. **Filtering**: Only search documents from specific sources
# 3. **Debugging**: Tracking which documents are being retrieved
# 4. **Analytics**: Understanding which sources are most useful

# %%
# Creating multiple documents (like a mini knowledge base)
documents = [
    Document(
        page_content="Python is a high-level programming language.",
        metadata={"category": "programming", "difficulty": "beginner"}
    ),
    Document(
        page_content="Machine learning is a subset of artificial intelligence.",
        metadata={"category": "AI", "difficulty": "intermediate"}
    ),
    Document(
        page_content="RAG combines retrieval and generation for better LLM outputs.",
        metadata={"category": "AI", "difficulty": "advanced"}
    )
]

# Print all documents
for i, doc in enumerate(documents, 1):
    print(f"\n📄 Document {i}:")
    print(f"   Content: {doc.page_content}")
    print(f"   Category: {doc.metadata['category']}")
    print(f"   Difficulty: {doc.metadata['difficulty']}")
# Out:
# 📄 Document 1:
#    Content: Python is a high-level programming language.
#    Category: programming
#    Difficulty: beginner
#
# 📄 Document 2:
#    Content: Machine learning is a subset of artificial intelligence.
#    Category: AI
#    Difficulty: intermediate
#
# 📄 Document 3:
#    Content: RAG combines retrieval and generation for better LLM outputs.
#    Category: AI
#    Difficulty: advanced

# %% [markdown]
# ### 4.2 LCEL (LangChain Expression Language) 🔗
#
# ### 🔰 BEGINNER
#
# **LCEL** is a way to connect different components using the pipe operator `|`.
#
# Think of it like a factory assembly line:
# ```
# Input → Component 1 → Component 2 → Component 3 → Output
# ```
#
# ### Before LCEL (Old Way - Messy!):
# ```python
# output = component3(component2(component1(input)))
# ```
#
# ### With LCEL (New Way - Clean!):
# ```python
# chain = component1 | component2 | component3
# output = chain.invoke(input)
# ```

# %% [markdown]
# ### 🎓 INTERMEDIATE: LCEL Deep Dive
#
# LCEL provides:
# - **Streaming**: Stream outputs as they're generated
# - **Batch Processing**: Process multiple inputs efficiently
# - **Async Support**: Non-blocking operations
# - **Debugging**: Better error messages and logging
# - **Type Safety**: Better IDE autocomplete
#
# **Key Methods:**
# - `.invoke(input)`: Process single input
# - `.batch([input1, input2])`: Process multiple inputs
# - `.stream(input)`: Stream output tokens
# - `.ainvoke(input)`: Async version of invoke

# %%
# Simple LCEL Example: String Transformation Chain
from langchain_core.runnables import RunnableLambda

# Create simple transformation functions
def uppercase(text: str) -> str:
    """Convert text to uppercase"""
    print(f"  Step 1: uppercase → {text.upper()}")
    return text.upper()

def add_prefix(text: str) -> str:
    """Add a prefix to text"""
    result = f"RESULT: {text}"
    print(f"  Step 2: add_prefix → {result}")
    return result

def add_emoji(text: str) -> str:
    """Add emoji to text"""
    result = f"✅ {text}"
    print(f"  Step 3: add_emoji → {result}")
    return result

# Create runnables (components that can be chained)
uppercase_runnable = RunnableLambda(uppercase)
prefix_runnable = RunnableLambda(add_prefix)
emoji_runnable = RunnableLambda(add_emoji)

# Build the chain using LCEL
chain = uppercase_runnable | prefix_runnable | emoji_runnable

# Execute the chain
print("Input: 'hello langchain'")
print("\nProcessing:")
result = chain.invoke("hello langchain")
print(f"\nFinal Output: {result}")
# Out:
# Input: 'hello langchain'
#
# Processing:
#   Step 1: uppercase → HELLO LANGCHAIN
#   Step 2: add_prefix → RESULT: HELLO LANGCHAIN
#   Step 3: add_emoji → ✅ RESULT: HELLO LANGCHAIN
#
# Final Output: ✅ RESULT: HELLO LANGCHAIN

# %% [markdown]
# ### 4.3 Chains 🔗
#
# ### 🔰 BEGINNER
#
# A **Chain** is a sequence of operations. Common chain types:
#
# 1. **Simple Chain**: Input → Process → Output
# 2. **RAG Chain**: Query → Retrieve → Generate → Answer
# 3. **Multi-step Chain**: Input → Step 1 → Step 2 → Step 3 → Output
#
# We'll build complex chains in later notebooks!

# %% [markdown]
# <a id="quick-start"></a>
# ## 5. Quick Start Example 🚀
#
# ### 🔰 BEGINNER: Your First LLM Call
#
# Let's make our first call to an LLM using LangChain!

# %%
# Import ChatOpenAI (the LLM interface) - LLM call example for LangChain 1.0+ OpenAI
from langchain_openai import ChatOpenAI

# Initialize the LLM
# model: Which GPT model to use
# temperature: 0 = deterministic, 1 = creative
llm = ChatOpenAI(
    model="gpt-3.5-turbo",  # Cheaper, faster model for learning
    temperature=0  # Deterministic outputs for learning
)

# Make a simple call
response = llm.invoke("What is LangChain in one sentence?")

# Print the response
print("Question: What is LangChain in one sentence?")
print(f"\nAnswer: {response.content}")
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[6], line 13
#       7 llm = ChatOpenAI(
#       8     model="gpt-3.5-turbo",  # Cheaper, faster model for learning
#       9     temperature=0  # Deterministic outputs for learning
#      10 )
#      12 # Make a simple call
# ---> 13 response = llm.invoke("What is LangChain in one sentence?")
#      15 # Print the response
#      16 print("Question: What is LangChain in one sentence?")
#
# File ~/Desktop/Ultimate RAG Bootcamp /simple-rag-langchain/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:385, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     371 @override
#     372 def invoke(
#     373     self,
#    (...)    378     **kwargs: Any,
#     379 ) -> AIMessage:
#     380     config = ensure_config(config)
#     381     return cast(
#     382         "AIMessage",
#     383         cast(
#     384             "ChatGeneration",
# --> 385             self.generate_prompt(
#     386                 [self._convert_input(input)],
#     387                 stop=stop,
#     388                 callbacks=config.get("callbacks"),
#     389                 tags=config.get("tags"),
#     390                 metadata=config.get("metadata"),
#     391                 run_name=config.get("run_name"),
#     392                 run_id=config.pop("run_id", None),
#     393                 **kwargs,
#     394             ).generations[0][0],
#     395         ).message,
#     396     )
#
# File ~/Desktop/Ultimate RAG Bootcamp /simple-rag-langchain/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1104, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1095 @override
#    1096 def generate_prompt(
#    1097     self,
#    (...)   1101     **kwargs: Any,
#    1102 ) -> LLMResult:
#    1103     prompt_messages = [p.to_messages() for p in prompts]
# -> 1104     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/Desktop/Ultimate RAG Bootcamp /simple-rag-langchain/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:914, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     911 for i, m in enumerate(input_messages):
#     912     try:
#     913         results.append(
# --> 914             self._generate_with_cache(
#     915                 m,
#     916                 stop=stop,
#     917                 run_manager=run_managers[i] if run_managers else None,
#     918                 **kwargs,
#     919             )
#     920         )
#     921     except BaseException as e:
#     922         if run_managers:
#
# File ~/Desktop/Ultimate RAG Bootcamp /simple-rag-langchain/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1208, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1206     result = generate_from_stream(iter(chunks))
#    1207 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1208     result = self._generate(
#    1209         messages, stop=stop, run_manager=run_manager, **kwargs
#    1210     )
#    1211 else:
#    1212     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/Desktop/Ultimate RAG Bootcamp /simple-rag-langchain/.venv/lib/python3.12/site-packages/langchain_openai/chat_models/base.py:1213, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1211     if raw_response is not None and hasattr(raw_response, "http_response"):
#    1212         e.response = raw_response.http_response  # type: ignore[attr-defined]
# -> 1213     raise e
#    1214 if (
#    1215     self.include_response_headers
#    1216     and raw_response is not None
#    1217     and hasattr(raw_response, "headers")
#    1218 ):
#    1219     generation_info = {"headers": dict(raw_response.headers)}
#
# File ~/Desktop/Ultimate RAG Bootcamp /simple-rag-langchain/.venv/lib/python3.12/site-packages/langchain_openai/chat_models/base.py:1208, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1201         return _construct_lc_result_from_responses_api(
#    1202             response,
#    1203             schema=original_schema_obj,
#    1204             metadata=generation_info,
#    1205             output_version=self.output_version,
#    1206         )
#    1207     else:
# -> 1208         raw_response = self.client.with_raw_response.create(**payload)
#    1209         response = raw_response.parse()
#    1210 except Exception as e:
#
# File ~/Desktop/Ultimate RAG Bootcamp /simple-rag-langchain/.venv/lib/python3.12/site-packages/openai/_legacy_response.py:364, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     360 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     362 kwargs["extra_headers"] = extra_headers
# --> 364 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File ~/Desktop/Ultimate RAG Bootcamp /simple-rag-langchain/.venv/lib/python3.12/site-packages/openai/_utils/_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File ~/Desktop/Ultimate RAG Bootcamp /simple-rag-langchain/.venv/lib/python3.12/site-packages/openai/resources/chat/completions/completions.py:1189, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1142 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1143 def create(
#    1144     self,
#    (...)   1186     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1187 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1188     validate_response_format(response_format)
# -> 1189     return self._post(
#    1190         "/chat/completions",
#    1191         body=maybe_transform(
#    1192             {
#    1193                 "messages": messages,
#    1194                 "model": model,
#    1195                 "audio": audio,
#    1196                 "frequency_penalty": frequency_penalty,
#    1197                 "function_call": function_call,
#    1198                 "functions": functions,
#    1199                 "logit_bias": logit_bias,
#    1200                 "logprobs": logprobs,
#    1201                 "max_completion_tokens": max_completion_tokens,
#    1202                 "max_tokens": max_tokens,
#    1203                 "metadata": metadata,
#    1204                 "modalities": modalities,
#    1205                 "n": n,
#    1206                 "parallel_tool_calls": parallel_tool_calls,
#    1207                 "prediction": prediction,
#    1208                 "presence_penalty": presence_penalty,
#    1209                 "prompt_cache_key": prompt_cache_key,
#    1210                 "prompt_cache_retention": prompt_cache_retention,
#    1211                 "reasoning_effort": reasoning_effort,
#    1212                 "response_format": response_format,
#    1213                 "safety_identifier": safety_identifier,
#    1214                 "seed": seed,
#    1215                 "service_tier": service_tier,
#    1216                 "stop": stop,
#    1217                 "store": store,
#    1218                 "stream": stream,
#    1219                 "stream_options": stream_options,
#    1220                 "temperature": temperature,
#    1221                 "tool_choice": tool_choice,
#    1222                 "tools": tools,
#    1223                 "top_logprobs": top_logprobs,
#    1224                 "top_p": top_p,
#    1225                 "user": user,
#    1226                 "verbosity": verbosity,
#    1227                 "web_search_options": web_search_options,
#    1228             },
#    1229             completion_create_params.CompletionCreateParamsStreaming
#    1230             if stream
#    1231             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1232         ),
#    1233         options=make_request_options(
#    1234             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1235         ),
#    1236         cast_to=ChatCompletion,
#    1237         stream=stream or False,
#    1238         stream_cls=Stream[ChatCompletionChunk],
#    1239     )
#
# File ~/Desktop/Ultimate RAG Bootcamp /simple-rag-langchain/.venv/lib/python3.12/site-packages/openai/_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Desktop/Ultimate RAG Bootcamp /simple-rag-langchain/.venv/lib/python3.12/site-packages/openai/_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %%
# Import Gemini (LangChain integration)
from dotenv import load_dotenv
import os

# Load .env file
load_dotenv()

# Import Gemini (LangChain integration)
from langchain_google_genai import GoogleGenerativeAI

# Initialize the LLM
llm = GoogleGenerativeAI(
    model="gemini-2.5-flash",   # Fast, cheap model
    temperature=0,              # Deterministic
    api_key=os.getenv("GOOGLE_API_KEY")
)

# Make a simple call
response = llm.invoke("What is LangChain in one sentence?")

# Print the response
print("Question: What is LangChain in one sentence?")
print("\nAnswer:", response)
# Out:
# Question: What is LangChain in one sentence?
#
# Answer: LangChain is a development framework that helps build applications powered by large language models (LLMs) by enabling them to connect with external data sources and tools, and chain together complex operations.

# %% [markdown]
# ### 🎓 INTERMEDIATE: Understanding the Response Object

# %%
# The response is an AIMessage object with metadata
print("Response Type:", type(response))
print("\nContent:", response.content)
print("\nResponse Metadata:")
print(response.response_metadata)

# Access specific metadata
if 'token_usage' in response.response_metadata:
    usage = response.response_metadata['token_usage']
    print(f"\nTokens Used:")
    print(f"  Prompt: {usage.get('prompt_tokens', 'N/A')}")
    print(f"  Completion: {usage.get('completion_tokens', 'N/A')}")
    print(f"  Total: {usage.get('total_tokens', 'N/A')}")
# Out:
# Response Type: <class 'langchain_core.messages.ai.AIMessage'>
#
# Content: LangChain is a decentralized language learning platform that uses blockchain technology to connect language learners with native speakers for personalized lessons.
#
# Response Metadata:
# {'token_usage': {'completion_tokens': 23, 'prompt_tokens': 15, 'total_tokens': 38, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-CcMehhBj1xaPUpjJM7gxISZcglUdA', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}
#
# Tokens Used:
#   Prompt: 15
#   Completion: 23
#   Total: 38

# %% [markdown]
# ### 🔰 BEGINNER: Using Prompts
#
# Instead of plain strings, use **prompt templates** for better control:

# %%
from langchain_core.prompts import ChatPromptTemplate

# Create a prompt template
# {topic} is a variable we'll fill in later
prompt = ChatPromptTemplate.from_template(
    "Explain {topic} in simple terms suitable for beginners."
)

# View the prompt structure
print("Prompt Template:")
print(prompt.messages[0].prompt.template)
# Out:
# Prompt Template:
# Explain {topic} in simple terms suitable for beginners.

# %%
# Build a chain: Prompt → LLM
from langchain_core.output_parsers import StrOutputParser

# Components:
# 1. prompt: Formats the input
# 2. llm: Generates the response
# 3. StrOutputParser: Extracts just the text from the response

chain = prompt | llm | StrOutputParser()

# Use the chain with different topics
topics = ["machine learning", "embeddings", "vector databases"]

for topic in topics:
    print(f"\n{'='*60}")
    print(f"Topic: {topic.upper()}")
    print('='*60)
    
    # Invoke the chain
    explanation = chain.invoke({"topic": topic})
    print(explanation)
# Out:
# ============================================================
# Topic: MACHINE LEARNING
# ============================================================
# Machine learning is a type of technology that allows computers to learn and improve from experience without being explicitly programmed. It involves creating algorithms that can analyze and interpret data, identify patterns, and make decisions or predictions based on that data. Essentially, machine learning enables computers to learn from data and make decisions or predictions without human intervention.
#
# ============================================================
# Topic: EMBEDDINGS
# ============================================================
# Embeddings are a way to represent words or objects as numerical vectors in a high-dimensional space. These vectors capture the meaning and relationships between words or objects based on their context in a given dataset. By using embeddings, we can perform various natural language processing tasks such as sentiment analysis, language translation, and text classification more effectively. Essentially, embeddings help computers understand and process language more like humans do.
#
# ============================================================
# Topic: VECTOR DATABASES
# ============================================================
# Vector databases are a type of database that store and manage data in a way that is optimized for handling geometric and spatial data. This means that instead of storing data in traditional rows and columns like a spreadsheet, vector databases store data as points, lines, and polygons.
#
# This type of database is commonly used in applications that require the storage and analysis of geographic information, such as mapping software, GPS systems, and location-based services. By organizing data in this way, vector databases can quickly and efficiently perform operations like finding the distance between two points, calculating the area of a polygon, or determining the intersection of two lines.
#
# Overall, vector databases are a powerful tool for managing and analyzing spatial data, making them essential for a wide range of industries and applications.

# %% [markdown]
# ### 🎓 INTERMEDIATE: Batch Processing
#
# Process multiple inputs efficiently using `.batch()`:

# %%
# Batch process multiple topics at once
topics_batch = [
    {"topic": "RAG"},
    {"topic": "LCEL"},
    {"topic": "LangChain agents"}
]

# Batch processing is more efficient than calling invoke() multiple times
results = chain.batch(topics_batch)

# Print results
for i, (input_dict, result) in enumerate(zip(topics_batch, results), 1):
    print(f"\n{i}. {input_dict['topic'].upper()}:")
    print(f"   {result[:100]}...")  # Print first 100 chars
# Out:
# 1. RAG:
#    RAG stands for Red, Amber, Green. It is a simple system used to categorize and prioritize tasks or p...
#
# 2. LCEL:
#    LCEL stands for "Lowest Common End Level." It is a term used in the field of education to describe t...
#
# 3. LANGCHAIN AGENTS:
#    LangChain agents are software programs that help facilitate communication between different language...

# %% [markdown]
# <a id="comparison"></a>
# ## 6. LangChain vs Traditional ML Pipelines 🆚
#
# ### 🔰 BEGINNER: Key Differences
#
# | Aspect | Traditional ML | LangChain |
# |--------|---------------|------------|
# | **Setup** | Complex, manual | Pre-built components |
# | **Integration** | Write custom code | Use existing integrations |
# | **Composability** | Difficult to chain | Easy with LCEL |
# | **Debugging** | Manual logging | Built-in callbacks |
# | **Prototyping** | Slow | Very fast |
# | **Code Reuse** | Limited | High |
#
# ### Example: Building a Q&A System
#
# #### Without LangChain (50+ lines):
# ```python
# import openai
# import PyPDF2
# import faiss
# import numpy as np
#
# # 1. Load PDF manually
# def load_pdf(file_path):
#     reader = PyPDF2.PdfReader(file_path)
#     text = ""
#     for page in reader.pages:
#         text += page.extract_text()
#     return text
#
# # 2. Split text manually
# def split_text(text, chunk_size=1000):
#     chunks = []
#     for i in range(0, len(text), chunk_size):
#         chunks.append(text[i:i+chunk_size])
#     return chunks
#
# # 3. Create embeddings manually
# def create_embeddings(chunks):
#     embeddings = []
#     for chunk in chunks:
#         response = openai.Embedding.create(
#             input=chunk,
#             model="text-embedding-ada-002"
#         )
#         embeddings.append(response['data'][0]['embedding'])
#     return np.array(embeddings)
#
# # 4. Create vector store manually
# def create_vector_store(embeddings):
#     dimension = embeddings.shape[1]
#     index = faiss.IndexFlatL2(dimension)
#     index.add(embeddings)
#     return index
#
# # 5. Search manually
# def search(query, index, chunks):
#     query_embedding = openai.Embedding.create(
#         input=query,
#         model="text-embedding-ada-002"
#     )['data'][0]['embedding']
#
#     distances, indices = index.search(
#         np.array([query_embedding]), k=3
#     )
#     return [chunks[i] for i in indices[0]]
#
# # 6. Generate answer manually
# def generate_answer(query, context):
#     prompt = f"Context: {context}\n\nQuestion: {query}\n\nAnswer:"
#     response = openai.ChatCompletion.create(
#         model="gpt-3.5-turbo",
#         messages=[{"role": "user", "content": prompt}]
#     )
#     return response['choices'][0]['message']['content']
#
# # Use it:
# text = load_pdf("document.pdf")
# chunks = split_text(text)
# embeddings = create_embeddings(chunks)
# index = create_vector_store(embeddings)
# relevant_chunks = search("What is RAG?", index, chunks)
# answer = generate_answer("What is RAG?", " ".join(relevant_chunks))
# ```
#
# #### With LangChain (10 lines!):
# ```python
# from langchain_community.document_loaders import PyPDFLoader
# from langchain_text_splitters import RecursiveCharacterTextSplitter
# from langchain_openai import OpenAIEmbeddings, ChatOpenAI
# from langchain_community.vectorstores import FAISS
# from langchain_core.prompts import ChatPromptTemplate
# from langchain_core.output_parsers import StrOutputParser
# from langchain_core.runnables import RunnablePassthrough
#
# # Load, split, embed, and store
# docs = PyPDFLoader("document.pdf").load()
# chunks = RecursiveCharacterTextSplitter(chunk_size=1000).split_documents(docs)
# vectorstore = FAISS.from_documents(chunks, OpenAIEmbeddings())
# retriever = vectorstore.as_retriever()
#
# # Build RAG chain
# prompt = ChatPromptTemplate.from_template(
#     "Context: {context}\n\nQuestion: {question}\n\nAnswer:"
# )
# chain = (
#     {"context": retriever, "question": RunnablePassthrough()}
#     | prompt | ChatOpenAI() | StrOutputParser()
# )
#
# # Use it:
# answer = chain.invoke("What is RAG?")
# ```
#
# **50+ lines → 10 lines!** 🎉

# %% [markdown]
# <a id="summary"></a>
# ## 7. Summary & Next Steps 📝
#
# ### 🎉 What You Learned
#
# ✅ **LangChain** is a framework that simplifies building LLM applications
#
# ✅ **Architecture** is modular: loaders, splitters, embeddings, vector stores, chains
#
# ✅ **Documents** contain `page_content` (text) and `metadata` (information about the text)
#
# ✅ **LCEL** uses the `|` operator to chain components together
#
# ✅ **Chains** connect multiple components to create complex workflows
#
# ✅ LangChain **dramatically reduces code** compared to manual implementations
#
# ### 🔰 For Beginners
# You now understand:
# - What LangChain is and why it's useful
# - How to set up your environment
# - Basic concepts: Documents and Chains
# - How to make your first LLM call
#
# ### 🎓 For Intermediate Learners
# You now understand:
# - LangChain's package structure (1.0+ reorganization)
# - LCEL internals and advantages
# - Metadata usage for filtering and citation
# - Batch processing for efficiency
#
# ### 📚 Next Notebooks
#
# 1. **Notebook 02**: Document Loaders (PDF, CSV, JSON, HTML)
# 2. **Notebook 03**: Text Splitting Strategies
# 3. **Notebook 04**: Embeddings and Vector Representations
# 4. **Notebook 05**: Vector Stores (FAISS, Chroma)
# 5. **Notebook 06**: Retrieval Strategies
# 6. **Notebook 07**: Complete RAG Pipeline
#
# ### 💡 Practice Exercises
#
# Before moving to the next notebook, try these:
#
# 1. **Easy**: Create 5 Documents about different topics with meaningful metadata
# 2. **Medium**: Build a chain that takes a topic and generates a haiku about it
# 3. **Advanced**: Create a chain that summarizes text in different styles (formal, casual, technical)
#
# ---
#
# ## 🎓 Additional Resources
#
# - [Official LangChain Documentation](https://python.langchain.com/docs/)
# - [LCEL Guide](https://python.langchain.com/docs/expression_language/)
# - [LangChain GitHub](https://github.com/langchain-ai/langchain)
#
# ---
#
# **Ready for more? Continue to Notebook 02: Document Loaders! 🚀**
